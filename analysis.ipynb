# %% [markdown]
# # Eploratory Data Analysis (EDA)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_excel('airline_ticket_dataset.xlsx')

# Display basic information
print("Dataset Shape:", df.shape)
print("\nFirst few rows:")
print(df.head())

print("\nData Types:")
print(df.dtypes)

print("\nMissing Values:")
print(df.isnull().sum())

print("\nBasic Statistics:")
print(df.describe())

print("\nColumn Names:")
print(df.columns.tolist())
# Out:
# Dataset Shape: (14004, 21)
#
# First few rows:
#    Year  quarter  citymarketid_1  citymarketid_2  \
# 0  2025        2           32467           31703
# 1  2025        2           32575           32457
# 2  2025        2           32575           31703
# 3  2025        2           31703           31454
# 4  2025        2           30977           31703
#
#                                    city1  \
# 0          Miami, FL (Metropolitan Area)
# 1    Los Angeles, CA (Metropolitan Area)
# 2    Los Angeles, CA (Metropolitan Area)
# 3  New York City, NY (Metropolitan Area)
# 4                            Chicago, IL
#
#                                    city2  nsmiles  passengers    fare  \
# 0  New York City, NY (Metropolitan Area)     1118       17955  208.52
# 1  San Francisco, CA (Metropolitan Area)      372       17310  157.68
# 2  New York City, NY (Metropolitan Area)     2510       13648  430.38
# 3                            Orlando, FL      989       12627  186.50
# ...

# %%
import plotly.express as px

fare_time["year_quarter"] = fare_time["Year"].astype(str) + "-Q" + fare_time["quarter"].astype(str)

fig = px.line(fare_time, x="year_quarter", y="fare", markers=True)
fig.update_layout(
    title="Average fare over time",
    xaxis_title="Year–Quarter",
    yaxis_title="Average fare",
    width=700,
    height=400
)
fig.write_html("fare_plot.html")
print("Saved to fare_plot.html — open it in your browser")
# Out:
# Saved to fare_plot.html — open it in your browser
